# %% [markdown]
# # Weather Forecasting

# %%
# Import all Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Load the Dataset
df = pd.read_csv(r"C:\Users\jayas\Downloads\GlobalWeatherRepository.csv")

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.describe()
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  49501.000000  49501.000000        4.950100e+04         49501.000000
# mean      19.140966     22.204052        1.726879e+09            22.963972
# std       24.480948     65.790750        6.411428e+06             9.207223
# min      -41.300000   -175.200000        1.715849e+09           -24.800000
# 25%        3.750000     -6.250000        1.721220e+09            18.200000
# 50%       17.250000     23.320000        1.726916e+09            25.300000
# 75%       40.400000     50.580000        1.732437e+09            29.000000
# max       64.150000    179.220000        1.737887e+09            49.200000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            49501.000000  49501.000000  49501.000000  49501.000000
# mean                73.336609      8.284489     13.336619    170.876104
# std                 16.572897      9.830255     15.818984    103.163971
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49501 entries, 0 to 49500
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       49501 non-null  object
#  1   location_name                 49501 non-null  object
#  2   latitude                      49501 non-null  float64
#  3   longitude                     49501 non-null  float64
#  4   timezone                      49501 non-null  object
#  5   last_updated_epoch            49501 non-null  int64
#  6   last_updated                  49501 non-null  object
#  7   temperature_celsius           49501 non-null  float64
#  8   temperature_fahrenheit        49501 non-null  float64
#  9   condition_text                49501 non-null  object
#  10  wind_mph                      49501 non-null  float64
#  11  wind_kph                      49501 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df.shape
# Out:
# (49501, 41)

# %%
sns.set(style="whitegrid")

# %%
summary_stats = df.describe()

# %% [markdown]
# # Data Visulization

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['temperature_celsius'], kde=True, bins=30, color='skyblue')
plt.title('Temperature Distribution (°C)', fontsize=16)
plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['humidity'], kde=True, bins=30, color='green')
plt.title('Humidity Distribution', fontsize=16)
plt.xlabel('Humidity (%)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
numerical_data = df.select_dtypes(include=['number'])
plt.figure(figsize=(16, 10))
corr_matrix = numerical_data.corr()
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
top_countries = df['country'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title('Top 10 Countries with Most Entries', fontsize=16)
plt.xlabel('Number of Entries', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.show()
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_30304\3587335805.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')

# %%
fig, axes = plt.subplots(3, 2, figsize=(18, 16))

sns.histplot(df['temperature_celsius'], kde=True, bins=30, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title('Temperature Distribution (°C)', fontsize=14)
axes[0, 0].set_xlabel('Temperature (°C)', fontsize=12)
axes[0, 0].set_ylabel('Frequency', fontsize=12)

sns.histplot(df['humidity'], kde=True, bins=30, ax=axes[0, 1], color='green')
axes[0, 1].set_title('Humidity Distribution (%)', fontsize=14)
axes[0, 1].set_xlabel('Humidity (%)', fontsize=12)
axes[0, 1].set_ylabel('Frequency', fontsize=12)

sns.histplot(df['wind_mph'], kde=True, bins=30, ax=axes[1, 0], color='blue')
axes[1, 0].set_title('Wind Speed Distribution (mph)', fontsize=14)
axes[1, 0].set_xlabel('Wind Speed (mph)', fontsize=12)
axes[1, 0].set_ylabel('Frequency', fontsize=12)

sns.boxplot(x=df['air_quality_PM2.5'], ax=axes[1, 1], color='purple')
axes[1, 1].set_title('Air Quality PM2.5 Levels', fontsize=14)
axes[1, 1].set_xlabel('PM2.5 (µg/m³)', fontsize=12)

sns.scatterplot(x=df['temperature_celsius'], y=df['humidity'], ax=axes[2, 0], color='orange', alpha=0.7)
axes[2, 0].set_title('Temperature vs Humidity', fontsize=14)
axes[2, 0].set_xlabel('Temperature (°C)', fontsize=12)
axes[2, 0].set_ylabel('Humidity (%)', fontsize=12)

sns.scatterplot(x=df['wind_mph'], y=df['air_quality_us-epa-index'], ax=axes[2, 1], color='green', alpha=0.7)
axes[2, 1].set_title('Wind Speed vs Air Quality Index', fontsize=14)
axes[2, 1].set_xlabel('Wind Speed (mph)', fontsize=12)
axes[2, 1].set_ylabel('Air Quality Index', fontsize=12)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(18, 18))

sns.scatterplot(x=df['temperature_celsius'], y=df['wind_mph'], ax=axes[0, 0], color='red')
axes[0, 0].set_title('Temperature vs Wind Speed (Scatter)', fontsize=14)
axes[0, 0].set_xlabel('Temperature (°C)', fontsize=12)
axes[0, 0].set_ylabel('Wind Speed (mph)', fontsize=12)

sns.scatterplot(x=df['humidity'], y=df['air_quality_us-epa-index'], ax=axes[0, 1], color='purple')
axes[0, 1].set_title('Humidity vs Air Quality Index', fontsize=14)
axes[0, 1].set_xlabel('Humidity (%)', fontsize=12)
axes[0, 1].set_ylabel('Air Quality Index', fontsize=12)

sns.boxplot(x=df['air_quality_PM10'], ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Air Quality PM10 Levels', fontsize=14)
axes[1, 0].set_xlabel('PM10 (µg/m³)', fontsize=12)

wind_air_quality_corr = df[['wind_mph', 'air_quality_us-epa-index']].corr()
sns.heatmap(wind_air_quality_corr, annot=True, cmap='coolwarm', ax=axes[1, 1])
axes[1, 1].set_title('Wind Speed vs Air Quality Index (Heatmap)', fontsize=14)

monthly_temp = df.groupby('country')['temperature_celsius'].mean()
monthly_temp.plot(kind='line', ax=axes[2, 0], color='brown')
axes[2, 0].set_title('Average Temperature by Country', fontsize=14)
axes[2, 0].set_xlabel('Country', fontsize=12)
axes[2, 0].set_ylabel('Average Temperature (°C)', fontsize=12)

top_wind_speeds = df[['location_name', 'wind_mph']].groupby('location_name').max().nlargest(10, 'wind_mph')
top_wind_speeds = (df[['location_name', 'wind_mph']].groupby('location_name').max().nlargest(10, 'wind_mph').reset_index())
top_wind_speeds.plot(kind='barh', x='location_name', y='wind_mph', ax=axes[2, 1], color='teal')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49501 entries, 0 to 49500
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       49501 non-null  object
#  1   location_name                 49501 non-null  object
#  2   latitude                      49501 non-null  float64
#  3   longitude                     49501 non-null  float64
#  4   timezone                      49501 non-null  object
#  5   last_updated_epoch            49501 non-null  int64
#  6   last_updated                  49501 non-null  object
#  7   temperature_celsius           49501 non-null  float64
#  8   temperature_fahrenheit        49501 non-null  float64
#  9   condition_text                49501 non-null  object
#  10  wind_mph                      49501 non-null  float64
#  11  wind_kph                      49501 non-null  float64
# ...

# %%
# Label Encoding
categorical_columns = ['timezone', 'last_updated', 'wind_direction', 'sunrise', 'sunset',
       'moonrise', 'moonset','country','location_name','condition_text','moon_phase'] 
for col in categorical_columns:
    if df[col].dtype == 'object':
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])

# %%
non_numeric_columns = df.select_dtypes(include=['object']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index([], dtype='object')

# %%
X = df.drop(['temperature_celsius'], axis=1)
y = df['temperature_celsius']

# %%
X
# Out:
#        country  location_name  latitude  longitude  timezone  \
# 0            0             98   34.5200    69.1800       104
# 1            1            225   41.3300    19.8200       166
# 2            2             11   36.7600     3.0500         2
# 3            3             14   42.5000     1.5200       133
# 4            4            122   -8.8400    13.2300        27
# ...        ...            ...       ...        ...       ...
# 49496      200             58   10.5000   -66.9167        49
# 49497      201             86   21.0333   105.8500        90
# 49498      202            205   15.3547    44.2067        83
# 49499      203            123  -15.4167    28.2833        28
# 49500      204             87  -17.8178    31.0447        20
#
#        last_updated_epoch  last_updated  temperature_fahrenheit  \
# 0              1715849100            22                    79.8
# 1              1715849100            15                    66.2
# ...

# %%
# Scaling the Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# RNN Based Model

# %%
# Splitting The Data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
model = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1, activation='linear') 
])
# Out:
# c:\Users\jayas\OneDrive\Desktop\New folder\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)
loss, mae = model.evaluate(X_test, y_test)
print(f"Mean Absolute Error on Test Data: {mae}")
# Out:
# Epoch 1/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 112.7298 - mae: 6.1134 - val_loss: 2.5702 - val_mae: 1.2081
# Epoch 2/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 23.1601 - mae: 2.5828 - val_loss: 1.0386 - val_mae: 0.8062
# Epoch 3/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 10.3950 - mae: 2.1316 - val_loss: 0.6981 - val_mae: 0.6859
# Epoch 4/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 5.7984 - mae: 1.8021 - val_loss: 1.2119 - val_mae: 0.9489
# Epoch 5/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 4.3636 - mae: 1.5885 - val_loss: 0.6941 - val_mae: 0.6876
# Epoch 6/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 3.4032 - mae: 1.4005 - val_loss: 1.5552 - val_mae: 1.0055
# Epoch 7/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.7745 - mae: 1.2635 - val_loss: 4.3555 - val_mae: 1.7952
# Epoch 8/50
# 1238/1238 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 2.6236 - mae: 1.1931 - val_loss: 3.4053 - val_mae: 1.5611
# ...

# %%
predictions = model.predict(X_test)
# Out:
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Advanced Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Support Vector Regressor (SVR)": SVR(kernel='rbf')
}

# %%
results = {}

# %%
for model_name, model in models.items():
    model.fit(X_train, y_train) 
    predictions = model.predict(X_test) 
    mae = mean_absolute_error(y_test, predictions) 
    results[model_name] = mae

# %%
print("Model Performance (MAE):")
for model_name, mae in results.items():
    print(f"{model_name}: {mae:.4f}")
# Out:
# Model Performance (MAE):
# Linear Regression: 0.0192
# Random Forest: 0.0084
# Gradient Boosting: 0.0553
# Decision Tree: 0.0085
# Support Vector Regressor (SVR): 0.2881

# %%
best_model_name = min(results, key=results.get)
print(f"\nBest Model: {best_model_name} with MAE: {results[best_model_name]:.4f}")
# Out:
# Best Model: Random Forest with MAE: 0.0084

# %%
X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# # Hyperparameter Tuning

# %%
rf_model = RandomForestRegressor(random_state=0, warm_start=True)
param_dist = {
    'n_estimators': [100, 200, 500], 
    'max_depth': [None, 10, 20], 
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2],  
    'max_features': ['auto', 'sqrt'], 
    'bootstrap': [True]  
}

random_search = RandomizedSearchCV(
    estimator=rf_model, 
    param_distributions=param_dist, 
    n_iter=50, 
    scoring='neg_mean_absolute_error', 
    cv=3,  
    verbose=2, 
    random_state=0, 
    n_jobs=-1  
)
random_search.fit(X_train_scaled[:int(len(X_train_scaled)*0.5)], y_train[:int(len(y_train)*0.5)])
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# c:\Users\jayas\OneDrive\Desktop\New folder\venv\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 84 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 74 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\jayas\OneDrive\Desktop\New folder\venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\jayas\OneDrive\Desktop\New folder\venv\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
print("Best Parameters: ", random_search.best_params_)
print("Best Score: ", random_search.best_score_)
# Out:
# Best Parameters:  {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
# Best Score:  -0.2191081798585435

# %%
best_rf_model = random_search.best_estimator_
best_rf_model.fit(X_train_scaled, y_train)
# Out:
# c:\Users\jayas\OneDrive\Desktop\New folder\venv\Lib\site-packages\sklearn\ensemble\_forest.py:466: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn(
# RandomForestRegressor(max_depth=20, max_features='sqrt', min_samples_split=5,
#                       n_estimators=200, random_state=0, warm_start=True)

# %%
from sklearn.metrics import mean_absolute_error
y_pred = best_rf_model.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
print("Test MAE for Tuned Random Forest Model:", mae)
# Out:
# Test MAE for Tuned Random Forest Model: 0.19350685055282293

# %%
pip install geopandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/16.2 MB 14.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/16.2 MB 16.1 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/16.2 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/16.2 MB 17.4 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 17.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 13.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.2 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 11.2 MB/s eta 0:00:00
# ...

# %%
from sklearn.ensemble import IsolationForest
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# %%
def detect_anomalies_zscore(data, column, threshold=3):
    z_scores = (data[column] - data[column].mean()) / data[column].std()
    anomalies = data[np.abs(z_scores) > threshold]
    return anomalies
if 'temperature' in df.columns:
    anomalies_zscore = detect_anomalies_zscore(df, 'temperature')
    print("Anomalies detected using Z-Score:")
    print(anomalies_zscore)

# %%
numerical_features = df.select_dtypes(include=[np.number])
isolation_forest = IsolationForest(contamination=0.05, random_state=42)
df['anomaly_score'] = isolation_forest.fit_predict(numerical_features)

# %%
anomalies_iforest = df[df['anomaly_score'] == -1]
print("Anomalies detected using Isolation Forest:")
print(anomalies_iforest)
# Out:
# Anomalies detected using Isolation Forest:
#        country  location_name  latitude  longitude  timezone  \
# 4            4            122   -8.8400    13.2300        27
# 35          35            206  -33.4500   -70.6700        75
# 36          36             36   39.9300   116.3900       118
# 68          68             85   14.6200   -90.5300        56
# 78          78             95   -6.2100   106.8500       102
# ...        ...            ...       ...        ...       ...
# 49420      121            229   47.9167   106.9167       125
# 49429      129            241  -41.3000   174.7833       179
# 49448      147             52   44.4333    26.1000       139
# 49457      156            195   24.6408    46.7728       116
# 49492      195            239   48.0792  -123.0439        64
#
#        last_updated_epoch  last_updated  temperature_celsius  \
# 4              1715849100            12                 26.0
# 35             1715849100             3                  1.0
# ...

# %%
if 'temperature' in df.columns and 'humidity' in df.columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='temperature', y='humidity', hue='anomaly_score', palette='coolwarm')
    plt.title("Anomalies Detected Using Isolation Forest")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
if 'latitude' in df.columns and 'longitude' in df.columns:
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(
        df['longitude'], df['latitude'],
        c=df['temperature'] if 'temperature' in df.columns else 'blue',
        cmap='coolwarm',  
        alpha=0.7, s=50 
    )
    if 'temperature' in df.columns:
        cbar = plt.colorbar(scatter)
        cbar.set_label('Temperature')
    plt.title('Spatial Analysis: Geographical Distribution of Data Points', fontsize=16)
    plt.xlabel('Longitude', fontsize=12)
    plt.ylabel('Latitude', fontsize=12)
    plt.grid(alpha=0.5)
    plt.show()

else:
    print("Latitude and Longitude columns are missing in the dataset.")
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_25472\3031336524.py:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(
